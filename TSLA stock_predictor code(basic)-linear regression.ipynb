# %%
import pandas as pd

# %%
df=pd.read_csv("TSLA.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
df["Date"]=pd.to_datetime(df["Date"])
df["Date"]
# Out:
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 2411   2020-01-28
# 2412   2020-01-29
# 2413   2020-01-30
# 2414   2020-01-31
# 2415   2020-02-03
# Name: Date, Length: 2416, dtype: datetime64[ns]

# %%
df["year"]=df["Date"].dt.year
df["month"]=df["Date"].dt.month
df["day"]=df["Date"].dt.day
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1    2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2    2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3    2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4    2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...         ...         ...         ...         ...         ...         ...
# 2411 2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412 2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413 2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414 2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415 2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume  year  month  day
# 0     18766300  2010      6   29
# 1     17187100  2010      6   30
# 2      8218800  2010      7    1
# 3      5139800  2010      7    2
# 4      6866900  2010      7    6
# ...        ...   ...    ...  ...
# 2411  11788500  2020      1   28
# 2412  17801500  2020      1   29
# 2413  29005700  2020      1   30
# 2414  15719300  2020      1   31
# 2415  47065000  2020      2    3
#
# [2416 rows x 10 columns]

# %%
df.drop(["Date"],axis=1)
# Out:
#             Open        High         Low       Close   Adj Close    Volume  \
# 0      19.000000   25.000000   17.540001   23.889999   23.889999  18766300
# 1      25.790001   30.420000   23.299999   23.830000   23.830000  17187100
# 2      25.000000   25.920000   20.270000   21.959999   21.959999   8218800
# 3      23.000000   23.100000   18.709999   19.200001   19.200001   5139800
# 4      20.000000   20.000000   15.830000   16.110001   16.110001   6866900
# ...          ...         ...         ...         ...         ...       ...
# 2411  568.489990  576.809998  558.080017  566.900024  566.900024  11788500
# 2412  575.690002  589.799988  567.429993  580.989990  580.989990  17801500
# 2413  632.419983  650.880005  618.000000  640.809998  640.809998  29005700
# 2414  640.000000  653.000000  632.520020  650.570007  650.570007  15719300
# 2415  673.690002  786.140015  673.520020  780.000000  780.000000  47065000
#
#       year  month  day
# 0     2010      6   29
# 1     2010      6   30
# 2     2010      7    1
# 3     2010      7    2
# 4     2010      7    6
# ...    ...    ...  ...
# 2411  2020      1   28
# 2412  2020      1   29
# 2413  2020      1   30
# 2414  2020      1   31
# 2415  2020      2    3
#
# [2416 rows x 9 columns]

# %%
from sklearn import linear_model

# %%
from matplotlib import pyplot as plt

# %%
x=df["Open"]

plt.subplot(1,2,1)
plt.plot(x)
plt.title("OPEN")
plt.xlable("open_price")
plt.ylable("cost_in_$")


plt.subplot(1,2,2)
plt.plot(df["Close"])

plt.title("CLOSE")
plt.title("OPEN")
plt.xlable("open_price")
plt.ylable("cost_in_$")

plt.show()

# %%
x=df[["year","month","day","High","Low"]]
y=df[["Open","Close"]]

# %%
reg=linear_model.LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[2020,2,3,786.140015,673.520020]])
# Out:
# C:\Users\91824\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[717.09562566, 744.54235602]])

# %%
reg.predict([[2023,11,15,226.54,236.33]])
# Out:
# C:\Users\91824\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[234.57177792, 228.53482064]])

# %%
reg.predict([[2023,11,17,226.54,236.33]])
# Out:
# C:\Users\91824\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[234.57030438, 228.53627775]])
